# %%
import pandas as pd
import pyreadstat
from scipy import io

# %%
df1 = pd.read_excel('data/Transactions_last_two_years.xlsx', sheetname='Sheet2')
df1.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py:188: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
#        ID          CustomerType CustomerStatus CustomerCateogry  AGE  \
# 0  100011             01 Family     Non-Member              NaN  NaN
# 1  100015  FAM-Executive Yearly         Active  FAM-Comp Lockin  NaN
# 2  100015  FAM-Executive Yearly         Active  FAM-Comp Lockin  NaN
# 3  100015  FAM-Executive Yearly         Active  FAM-Comp Lockin  NaN
# 4  100015  FAM-Executive Yearly         Active  FAM-Comp Lockin  NaN
#
#               CITY         ZIP TRANSACTION_DATE  JOIN_DATE  \
# 0       Lake Worth  33467-5221       2017-12-20 2004-10-01
# 1  West Bloomfield  48322-3139       2017-12-07 1993-01-01
# 2  West Bloomfield  48322-3139       2018-06-12 1993-01-01
# 3  West Bloomfield  48322-3139       2018-06-12 1993-01-01
# 4  West Bloomfield  48322-3139       2018-06-12 1993-01-01
#
# ...

# %%
databank = pd.read_csv('data/Detroit_databank/Detroit 2018 DataBank Public Data SPSS SAV.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (1,2,375,387,450,451,452,453,454,455,716,740,756,757) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
databank.head()
# Out:
#    ID lor lorca  move  wmove  hhsiz  oth_adults  num_children  age1  sex1  \
# 0   1  50     4     3    100      1           0             0    75     1
# 1   2  37    20     4    100      2           1             0    76     1
# 2   3  33    12     3    100      3           2             0    61     2
# 3   4  62    34     3    100      4           3             0    62     1
# 4   5  70     2     3    100      1           0             0    70     1
#
#    ...  anyshoah  anyshoahG vol  chabad  dischild cgoisr cgoisrc  anyisr  \
# 0  ...         2          2   0       2         2    999
# 1  ...         2          2   4       2         2    999
# 2  ...         2          2   0                 2    999
# 3  ...         2          2   1       1         2    100             100
# 4  ...         2          2   1                 2    999
#
#   citywork  city2
# 0             901
# 1      901    105
# 2      103    103
# 3             101
# 4      104    102
#
# [5 rows x 883 columns]
